# %%
def consumption(nunber, tax):
  # 消費税10%の計算式
  total = nunber * tax
  # 変数の値の出力
  print(f"{total}円")
  #関数を呼び出す
consumption(500, 1.1)
# Out:
# 550.0円

# %%
def consumption(nunber, tax):
  # 消費税10%の計算式
  return nunber * tax

print(f"{number}{tax}円")

  #関数を呼び出す
consumption(500, 1.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-720be44662b2> in <cell line: 5>()
#       3   return nunber * tax
#       4
# ----> 5 print(f"{number}{tax}円")
#       6
#       7   #関数を呼び出す
#
# NameError: name 'number' is not defined
