# %%
class Human:
  def __init__(self, name, age):
    # 属性の定義
    self.name = name
    self.age = age

def check_adult(self):
      if self.age >= 20:
        print("{} は大人".format(self.name))

      else:
        print("{} は子供".format(self.name))

# インスタンスの作成
human = [["やま", 77],
           ["ゆう", 7]]

#インスタンスのリストへ追加
human_list = []
for a in human:
  human_list.append((a[0], a[1]))

#メゾット
i = 0
for b in human_list:
  Human(b[0], b[1]).check_adult()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-184cf6638e4b> in <cell line: 25>()
#      24 i = 0
#      25 for b in human_list:
# ---> 26   Human(b[0], b[1]).check_adult()
#
# AttributeError: 'Human' object has no attribute 'check_adult'

# %%
class Human:
  def __init__(self, name, age):
    # 属性の定義
    self.name = name
    self.age = age

  def check_adult(self):
    if self.age >= 20:
      print("{} は大人です".format(self.name))
    else:
      print("{} は未成年です".format(self.name))

# インスタンスを作成
data = [["一郎", 10],
         ["二朗", 12],
         ["三郎", 20],
         ["四郎", 22],
         ["五郎", 30]]

# human_listへインスタンスのリストを追加
human_list = []
for d in data:
  human_list.append((d[0], d[1]))

# human_listより各インスタンスのメソッドを実行
i = 0
for h in human_list:
  Human(h[0], h[1]).check_adult()
# Out:
# 一郎 は未成年です
# 二朗 は未成年です
# 三郎 は大人です
# 四郎 は大人です
# 五郎 は大人です
