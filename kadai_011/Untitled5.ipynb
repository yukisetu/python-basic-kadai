# %%
user_names = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

for user_name in user_names:
  print(user_name)

number = 0
while number < 8:
  print (user_names[number])
  number +=1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
