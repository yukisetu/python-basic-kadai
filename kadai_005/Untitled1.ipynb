# %%
# 台形の面積
upper_side = 10
lower_side = 20
height  = 5

# 台形の計算
print ((upper_side + lower_side ) * height / 2 )

# 計算結果と文字列
number = "75"
name = "cm²"

#　文字連結
print (number + name)
# Out:
# 75.0
# 75cm²
