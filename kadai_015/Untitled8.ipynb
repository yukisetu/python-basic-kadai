# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self, name, age):
    self.name = name
    self.age = age

human = Human("やま", 77)

print(human.name)
print(human.age)

human.printinfo("やま", 77)
# Out:
# やま
# 77
