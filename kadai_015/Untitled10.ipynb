# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self, name, age):
    self = name
    self = age

    print(name)
    print(age)

human = Human("やま", 77)



human.printinfo("やま", 77)
# Out:
# やま
# 77
